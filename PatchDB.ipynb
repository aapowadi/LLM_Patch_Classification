# %%
import pandas as pd

# %%
fs_patch = pd.read_csv('linux/xfs-patch_with_patches.csv')
fs_patch

# %%
fs_patch = pd.read_csv('dataset/xfs-patch_type_dataset.csv')
fs_patch

# %%
fs_patch.Description[0]

# %%
df = pd.read_parquet('PatchDB.parquet')
df

# %%
df.commit_message[0]

# %%
df.diff_code[0]
